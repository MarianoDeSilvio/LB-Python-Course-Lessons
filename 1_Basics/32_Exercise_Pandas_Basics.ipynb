# %%
import pandas as pd
from datasets import load_dataset

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# data_jobs.csv:   0%|          | 0.00/231M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/785741 [00:00<?, ? examples/s]

# %%
df['job_country'].value_counts()
# Out:
# job_country
# United States     206292
# India              51088
# United Kingdom     40375
# France             39922
# Germany            27694
#                    ...
# Guinea                 4
# Lesotho                3
# Mauritania             3
# Bhutan                 3
# Maldives               2
# Name: count, Length: 160, dtype: int64

# %%
df['job_country'].value_counts().head(20)
# Out:
# job_country
# United States     206292
# India              51088
# United Kingdom     40375
# France             39922
# Germany            27694
# Spain              25100
# Singapore          23696
# Sudan              21781
# Netherlands        20631
# Italy              17013
# Canada             16029
# Mexico             15139
# Poland             14793
# Portugal           14508
# Australia          12955
# South Africa       12414
# Belgium            12078
# Philippines        11786
# Ireland            11162
# Switzerland         9924
# Name: count, dtype: int64

# %%
df['job_country'].isin(['Argentina'])
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 785736    False
# 785737    False
# 785738    False
# 785739    False
# 785740    False
# Name: job_country, Length: 785741, dtype: bool

# %%
df['job_country'].isin(['Argentina']).any()
# Out:
# np.True_

# %%
Argen_Jobs = df[df['job_country'] == 'Argentina']

# %%
Argen_Jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8736 entries, 236 to 785672
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        8736 non-null   object
#  1   job_title              8736 non-null   object
#  2   job_location           8736 non-null   object
#  3   job_via                8736 non-null   object
#  4   job_schedule_type      8719 non-null   object
#  5   job_work_from_home     8736 non-null   bool
#  6   search_location        8736 non-null   object
#  7   job_posted_date        8736 non-null   datetime64[ns]
#  8   job_no_degree_mention  8736 non-null   bool
#  9   job_health_insurance   8736 non-null   bool
#  10  job_country            8736 non-null   object
#  11  salary_rate            33 non-null     object
#  12  salary_year_avg        32 non-null     float64
#  13  salary_hour_avg        1 non-null      float64
# ...

# %%
Spain_Jobs = df[df['job_country'] == 'Spain']

# %%
Spain_Jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25100 entries, 115 to 785620
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        25100 non-null  object
#  1   job_title              25100 non-null  object
#  2   job_location           25100 non-null  object
#  3   job_via                25100 non-null  object
#  4   job_schedule_type      25001 non-null  object
#  5   job_work_from_home     25100 non-null  bool
#  6   search_location        25100 non-null  object
#  7   job_posted_date        25100 non-null  datetime64[ns]
#  8   job_no_degree_mention  25100 non-null  bool
#  9   job_health_insurance   25100 non-null  bool
#  10  job_country            25100 non-null  object
#  11  salary_rate            148 non-null    object
#  12  salary_year_avg        144 non-null    float64
#  13  salary_hour_avg        4 non-null      float64
# ...

# %%
Spain_Jobs = Spain_Jobs[Spain_Jobs['salary_year_avg'].notna()]
Spain_Jobs
# Out:
#              job_title_short                                   job_title  \
# 4521       Software Engineer                  Power BI Solution Engineer
# 7170    Senior Data Engineer   Senior Software Engineer (Data Analytics)
# 12335         Data Scientist              DESARROLLADOR PYTHON - PYSPARK
# 13913      Software Engineer  Staff Quality Assurance Engineer (ETL/SQL)
# 17710           Data Analyst                         Master Data Analyst
# ...                      ...                                         ...
# 777078        Data Scientist         (Senior) Digital Analytics Engineer
# 781103          Data Analyst           Junior Data Analyst / After Sales
# 781830         Data Engineer                        Azure Data Architect
# 782773          Data Analyst                   Data Analyst - Operations
# 783528        Cloud Engineer              Elasticsearch + AWS Consultant
#
#             job_location          job_via job_schedule_type  \
# ...

# %%
Spain_Jobs.groupby('job_title_short')['salary_year_avg'].agg(['count','median','max','min']).sort_values(by='median', ascending=False)
# Out:
#                            count    median       max      min
# job_title_short
# Senior Data Scientist          7  157500.0  211475.0  45000.0
# Senior Data Engineer          11  147500.0  176500.0  72900.0
# Data Engineer                 35  133000.0  165000.0  56500.0
# Senior Data Analyst            9  111175.0  111175.0  89100.0
# Machine Learning Engineer     16  101029.0  225000.0  43200.0
# Data Analyst                  30   91977.0  155000.0  51014.0
# Cloud Engineer                 3   89100.0  125253.0  56700.0
# Data Scientist                20   88128.0  165000.0  56700.0
# Business Analyst               5   86400.0  185000.0  63000.0
# Software Engineer              8   77050.0  205000.0  56700.0
